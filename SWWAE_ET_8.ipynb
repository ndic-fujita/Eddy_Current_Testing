# %%
import tkinter as tk
from tkinter import filedialog
import os
import numpy as np
import re
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Conv1DTranspose, ZeroPadding1D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 符号付に変換する関数
def unsigned2signed(x):
    if x > 32767:
        return x - 65536
    return x

# %%
# 学習データの読み込み
def load_binary_data(folder_path):
    data = {}  # ファイルの拡張子と数字を除いたフルパスをキーとしたディクショナリ
    file_names = []  # ファイル名を格納するリスト

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            match = re.match(r'(.+?)\.d(\d+)', file)  # 正規表現で.d○○の形式のファイル名を捉える
            if match:
                file_name, data_index = match.groups()
                data_index = int(data_index)
                full_path = os.path.join(root, file)  # フルパス
                full_path_key = full_path[:-4]  # 拡張子と数字を除いたフルパス
                if full_path_key not in data or data_index > data[full_path_key][8]:
                    with open(full_path, 'rb') as in_file:
                        buf = in_file.read()
                    # 8つのセンサーデータをグループ化
                    sensor_data = [buf[i:i+8*2] for i in range(408, len(buf), 8*2)]
                    sensor_values = []  # センサーデータを格納するリスト
                    for i in range(8):
                        sensor_values.append([unsigned2signed(int.from_bytes(sensor[i*2:i*2+2], 'little')) for sensor in sensor_data])
                    # 拡張子の番号を追加してデータをタプルに格納
                    sensor_values.append(int(data_index))
                    data[full_path_key] = sensor_values  # センサーデータと拡張子の番号をタプルに格納
                    file_names.append(file_name)  # ファイル名をリストに追加

    return data, file_names

# Tkinterを初期化
root = tk.Tk()
root.withdraw()  # メインウィンドウを非表示にする

# フォルダを選択するためのダイアログを表示
folder_selected = filedialog.askdirectory()

if folder_selected:
    print("選択したフォルダ:", folder_selected)
    # フォルダ内のデータを読み込む
    data, data_filenames = load_binary_data(folder_selected)
    if data:
        print("データの読み込みが完了しました。")
    else:
        print("データが見つかりませんでした。")
else:
    print("フォルダが選択されませんでした。")

# Tkinterを終了
root.quit()

sensor_data_dict = {}  # センサーデータを格納するディクショナリ
for key, sensor_data in data.items():
    extension_number = sensor_data[-1]  # 拡張子の番号
    for i, sensor_value in enumerate(sensor_data[:-1]):  # 拡張子の番号を除くセンサーデータをループ
        sensor_key = f"{key}_{extension_number}_{i+1}"  # キーを生成
        if sensor_key not in sensor_data_dict:
            sensor_data_dict[sensor_key] = []  # キーが存在しない場合、空のリストを作成
        sensor_data_dict[sensor_key].append(sensor_value)  # キーに対応するリストにセンサーデータを追加

# データの形状を決定
num_samples = len(sensor_data_dict)
num_sensors = 8  # センサーの数

# 2次元のリストを初期化
data_matrix = [[None] * num_sensors for _ in range(num_samples)]

# センサーデータのみを保存する新しい変数を作成
sensor_data = []

# データを2次元リストと新しい変数に配置
for i, (key, sensor_values) in enumerate(sensor_data_dict.items()):
    data_matrix[i] = [key] + sensor_values  # キーとセンサーデータのリストを1つのリストに格納
    sensor_data.append(sensor_values)  # センサーデータのリストを新しい変数に格納
    
# 3次元のリストを2次元のリストに変換する
reshaped_sensor_data = []
for sample in sensor_data:
    for sensor_values in sample:
        reshaped_sensor_data.append(sensor_values)

sensor_data = reshaped_sensor_data
sensor_data_copy = sensor_data
# Out:
# 選択したフォルダ: C:/Users/r-fujita/Desktop/20240307/train
# データの読み込みが完了しました。

# %%
# テストデータの読み込み
def load_test_data(test_folder_path):
    test_data = {}  # ファイルの拡張子と数字を除いたフルパスをキーとしたディクショナリ
    test_file_names = []  # ファイル名を格納するリスト

    for root, dirs, files in os.walk(test_folder_path):
        for file in files:
            match = re.match(r'(.+?)\.d(\d+)', file)  # 正規表現で.d○○の形式のファイル名を捉える
            if match:
                file_name, data_index = match.groups()
                data_index = int(data_index)
                full_path = os.path.join(root, file)  # フルパス
                full_path_key = full_path[:-4]  # 拡張子と数字を除いたフルパス
                if full_path_key not in test_data or data_index > test_data[full_path_key][8]:
                    with open(full_path, 'rb') as in_file:
                        buf = in_file.read()
                    # 8つのセンサーデータをグループ化
                    sensor_data = [buf[i:i+8*2] for i in range(408, len(buf), 8*2)]
                    sensor_values = []  # センサーデータを格納するリスト
                    for i in range(8):
                        sensor_values.append([unsigned2signed(int.from_bytes(sensor[i*2:i*2+2], 'little')) for sensor in sensor_data])
                    # 拡張子の番号を追加してデータをタプルに格納
                    sensor_values.append(int(data_index))
                    test_data[full_path_key] = sensor_values  # センサーデータと拡張子の番号をタプルに格納
                    test_file_names.append(file_name)  # ファイル名をリストに追加

    return test_data, test_file_names

# Tkinterを初期化
root = tk.Tk()
root.withdraw()  # メインウィンドウを非表示にする

# テストデータのフォルダを選択するためのダイアログを表示
test_folder_path = filedialog.askdirectory()

if test_folder_path:
    print("選択したテストデータのフォルダ:", test_folder_path)
    # テストデータを読み込む
    test_data, test_data_filenames = load_test_data(test_folder_path)
    if test_data:
        print("テストデータの読み込みが完了しました。")
    else:
        print("テストデータが見つかりませんでした.")
else:
    print("テストデータのフォルダが選択されませんでした.")

test_sensor_data_dict = {}  # テストデータのセンサーデータを格納するディクショナリ
for key, test_sensor_data in test_data.items():
    extension_number = test_sensor_data[-1]  # 拡張子の番号
    for i, test_sensor_value in enumerate(test_sensor_data[:-1]):  # 拡張子の番号を除くセンサーデータをループ
        test_sensor_key = f"{key}_{extension_number}_{i+1}"  # キーを生成
        if test_sensor_key not in test_sensor_data_dict:
            test_sensor_data_dict[test_sensor_key] = []  # キーが存在しない場合、空のリストを作成
        test_sensor_data_dict[test_sensor_key].append(test_sensor_value)  # キーに対応するリストにテストデータのセンサーデータを追加

# データの形状を決定
num_test_samples = len(test_sensor_data_dict)
num_sensors = 8  # センサーの数

# テストデータの2次元のリストを初期化
test_data_matrix = [[None] * num_sensors for _ in range(num_test_samples)]

# テストデータのセンサーデータのみを保存する新しい変数を作成
test_sensor_data = []

# テストデータを2次元リストと新しい変数に配置
for i, (key, test_sensor_values) in enumerate(test_sensor_data_dict.items()):
    test_data_matrix[i] = [key] + test_sensor_values  # キーとセンサーデータのリストを1つのリストに格納
    test_sensor_data.append(test_sensor_values)  # テストデータのセンサーデータのリストを新しい変数に格納

# 3次元のリストを2次元のリストに変換する
reshaped_sensor_data = []
for sample in test_sensor_data:
    for test_sensor_values in sample:
        reshaped_sensor_data.append(test_sensor_values)

test_sensor_data = reshaped_sensor_data
test_sensor_data_copy = test_sensor_data
# Out:
# 選択したテストデータのフォルダ: C:/Users/r-fujita/Desktop/20240307/test
# テストデータの読み込みが完了しました。

# %%
# 検証用データの読み込み
def load_val_data(val_folder_path):
    val_data = {}  # ファイルの拡張子と数字を除いたフルパスをキーとしたディクショナリ
    val_file_names = []  # ファイル名を格納するリスト

    for root, dirs, files in os.walk(val_folder_path):
        for file in files:
            match = re.match(r'(.+?)\.d(\d+)', file)  # 正規表現で.d○○の形式のファイル名を捉える
            if match:
                file_name, data_index = match.groups()
                data_index = int(data_index)
                full_path = os.path.join(root, file)  # フルパス
                full_path_key = full_path[:-4]  # 拡張子と数字を除いたフルパス
                if full_path_key not in val_data or data_index > val_data[full_path_key][8]:
                    with open(full_path, 'rb') as in_file:
                        buf = in_file.read()
                    # 8つのセンサーデータをグループ化
                    sensor_data = [buf[i:i+8*2] for i in range(408, len(buf), 8*2)]
                    sensor_values = []  # センサーデータを格納するリスト
                    for i in range(8):
                        sensor_values.append([unsigned2signed(int.from_bytes(sensor[i*2:i*2+2], 'little')) for sensor in sensor_data])
                    # 拡張子の番号を追加してデータをタプルに格納
                    sensor_values.append(int(data_index))
                    val_data[full_path_key] = sensor_values  # センサーデータと拡張子の番号をタプルに格納
                    val_file_names.append(file_name)  # ファイル名をリストに追加

    return val_data, val_file_names

# Tkinterを初期化
root = tk.Tk()
root.withdraw()  # メインウィンドウを非表示にする

# 検証データのフォルダを選択するためのダイアログを表示
val_folder_path = filedialog.askdirectory()

if val_folder_path:
    print("選択した検証データのフォルダ:", val_folder_path)
    # 検証データを読み込む
    val_data, val_data_filenames = load_val_data(val_folder_path)
    if val_data:
        print("検証データの読み込みが完了しました。")
    else:
        print("検証データが見つかりませんでした.")
else:
    print("検証データのフォルダが選択されませんでした.")

val_sensor_data_dict = {}  # 検証データのセンサーデータを格納するディクショナリ
for key, val_sensor_data in val_data.items():
    extension_number = val_sensor_data[-1]  # 拡張子の番号
    for i, val_sensor_value in enumerate(val_sensor_data[:-1]):  # 拡張子の番号を除くセンサーデータをループ
        val_sensor_key = f"{key}_{extension_number}_{i+1}"  # キーを生成
        if val_sensor_key not in val_sensor_data_dict:
            val_sensor_data_dict[val_sensor_key] = []  # キーが存在しない場合、空のリストを作成
        val_sensor_data_dict[val_sensor_key].append(val_sensor_value)  # キーに対応するリストに検証データのセンサーデータを追加

# データの形状を決定
num_val_samples = len(val_sensor_data_dict)
num_sensors = 8  # センサーの数

# 検証データの2次元のリストを初期化
val_data_matrix = [[None] * num_sensors for _ in range(num_val_samples)]

# 検証データのセンサーデータのみを保存する新しい変数を作成
val_sensor_data = []

# 検証データを2次元リストと新しい変数に配置
for i, (key, val_sensor_values) in enumerate(val_sensor_data_dict.items()):
    val_data_matrix[i] = [key] + val_sensor_values  # キーとセンサーデータのリストを1つのリストに格納
    val_sensor_data.append(val_sensor_values)  # 検証データのセンサーデータのリストを新しい変数に格納

# 3次元のリストを2次元のリストに変換する
reshaped_sensor_data = []
for sample in val_sensor_data:
    for val_sensor_values in sample:
        reshaped_sensor_data.append(val_sensor_values)

val_sensor_data = reshaped_sensor_data
val_sensor_data_copy = val_sensor_data
# Out:
# 選択した検証データのフォルダ: C:/Users/r-fujita/Desktop/20240307/val
# 検証データの読み込みが完了しました。

# %%
# 絶対値表示にする
abs_sensor_data = [[abs(value) for value in sublist] for sublist in sensor_data]
abs_test_sensor_data = [[abs(value) for value in sublist] for sublist in test_sensor_data]
abs_val_sensor_data = [[abs(value) for value in sublist] for sublist in val_sensor_data]

# %%
# 管端部を削除する。
# sensor_dataの処理（右の端部の除去）
for i, waveform in enumerate(abs_sensor_data):
    backward_index = next((len(waveform) - 1 - j for j, x in enumerate(reversed(waveform)) if x > 2000), None)
    if backward_index is not None:
        desired_index = max(0, backward_index - 500)
        sensor_data[i] = sensor_data[i][:desired_index]

# test_sensor_dataの処理（右の端部の除去）
for i, waveform in enumerate(abs_test_sensor_data):
    backward_index = next((len(waveform) - 1 - j for j, x in enumerate(reversed(waveform)) if x > 2000), None)
    if backward_index is not None:
        desired_index = max(0, backward_index - 500)
        test_sensor_data[i] = test_sensor_data[i][:desired_index]

# val_sensor_dataの処理（右の端部の除去）
for i, waveform in enumerate(abs_val_sensor_data):
    backward_index = next((len(waveform) - 1 - j for j, x in enumerate(reversed(waveform)) if x > 2000), None)
    if backward_index is not None:
        desired_index = max(0, backward_index - 500)
        val_sensor_data[i] = val_sensor_data[i][:desired_index]

# sensor_dataの処理（左の端部の除去）
for i, waveform in enumerate(abs_sensor_data):
    forward_index = next((j for j, x in enumerate(waveform) if x > 2000), None)
    if forward_index is not None:
        desired_index = min(len(waveform), forward_index + 500)
        sensor_data[i] = sensor_data[i][desired_index:]

# test_sensor_dataの処理（左の端部の除去）
for i, waveform in enumerate(abs_test_sensor_data):
    forward_index = next((j for j, x in enumerate(waveform) if x > 2000), None)
    if forward_index is not None:
        desired_index = min(len(waveform), forward_index + 500)
        test_sensor_data[i] = test_sensor_data[i][desired_index:]

# val_sensor_dataの処理（左の端部の除去）
for i, waveform in enumerate(abs_val_sensor_data):
    forward_index = next((j for j, x in enumerate(waveform) if x > 2000), None)
    if forward_index is not None:
        desired_index = min(len(waveform), forward_index + 500)
        val_sensor_data[i] = val_sensor_data[i][desired_index:]

# %%
# mixのデータを削除する
del sensor_data[6::8]
del sensor_data[6::7]
del test_sensor_data[6::8]
del test_sensor_data[6::7]
del val_sensor_data[6::8]
del val_sensor_data[6::7]

# %%
empty_lists_sensor_data_indices = [i for i, data in enumerate(sensor_data) if not data]
empty_lists_test_sensor_data_indices = [i for i, data in enumerate(test_sensor_data) if not data]
empty_lists_val_sensor_data_indices = [i for i, data in enumerate(val_sensor_data) if not data]
print("sensor_data内の空のリストの数:", len(empty_lists_sensor_data_indices))
print("sensor_data内の空のリストのインデックス:", empty_lists_sensor_data_indices)
print("test_sensor_data内の空のリストの数:", len(empty_lists_test_sensor_data_indices))
print("test_sensor_data内の空のリストのインデックス:", empty_lists_test_sensor_data_indices)
print("val_sensor_data内の空のリストの数:", len(empty_lists_val_sensor_data_indices))
print("val_sensor_data内の空のリストのインデックス:", empty_lists_val_sensor_data_indices)
# Out:
# sensor_data内の空のリストの数: 0
# sensor_data内の空のリストのインデックス: []
# test_sensor_data内の空のリストの数: 0
# test_sensor_data内の空のリストのインデックス: []
# val_sensor_data内の空のリストの数: 0
# val_sensor_data内の空のリストのインデックス: []

# %%
keys = list(sensor_data_dict.keys())
print(keys[38])
# Out:
# C:/Users/r-fujita/Desktop/learning_data\FCC_E-2208\2019\#1\ASSORT\E-2208\APD000\001-006_0_7

# %%
# データ長を取得
sensor_data_lengths = [len(data) for data in sensor_data]
test_sensor_data_lengths = [len(data) for data in test_sensor_data]
val_sensor_data_lengths = [len(data) for data in val_sensor_data]
# ヒストグラムをプロット
plt.figure(figsize=(10, 6))
plt.hist(sensor_data_lengths, bins=50, alpha=0.5, color='blue', label='Train')
plt.hist(test_sensor_data_lengths, bins=50, alpha=0.5, color='red', label='NG')
plt.hist(val_sensor_data_lengths, bins=50, alpha=0.5, color='green', label='OK')
plt.xlabel('Data Length')
plt.ylabel('Frequency')
plt.title('Distribution of Data Lengths')
plt.legend()
plt.grid(True)
plt.show()

# %%
# データ長が4000未満及び15000以上のデータを削除する。

# 学習データ
# データ長が15000以上のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(sensor_data) if len(data) >= 12000]
# 対応するインデックスのデータを削除する
for index in sorted(indices_to_remove, reverse=True):
    del sensor_data[index]
# データ長が4000未満のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(sensor_data) if len(data) < 4000]
for index in sorted(indices_to_remove, reverse=True):
    del sensor_data[index]

# テストデータ
# データ長が15000以上のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(test_sensor_data) if len(data) >= 12000]
# 対応するインデックスのデータを削除する
for index in sorted(indices_to_remove, reverse=True):
    del test_sensor_data[index]
# データ長が4000未満のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(test_sensor_data) if len(data) < 4000]
for index in sorted(indices_to_remove, reverse=True):
    del test_sensor_data[index]

# 検証データ
# データ長が15000以上のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(val_sensor_data) if len(data) >= 12000]
# 対応するインデックスのデータを削除する
for index in sorted(indices_to_remove, reverse=True):
    del val_sensor_data[index]
# データ長が4000未満のデータのインデックスを取得する
indices_to_remove = [index for index, data in enumerate(val_sensor_data) if len(data) < 4000]
for index in sorted(indices_to_remove, reverse=True):
    del val_sensor_data[index]

# %%
# データの標準化
# 学習データ
sensor_data_sca = []
for i in range(len(sensor_data)):
    mean = np.mean(sensor_data[i])
    std = np.std(sensor_data[i])

    #標準化処理を実行
    standardization_sensor_data = (sensor_data[i] - mean) / std
    sensor_data_sca.append(standardization_sensor_data)

# テストデータ
test_sensor_data_sca = []
for i in range(len(test_sensor_data)):
    mean = np.mean(test_sensor_data[i])
    std = np.std(test_sensor_data[i])

    #標準化処理を実行
    standardization_test_sensor_data = (test_sensor_data[i] - mean) / std
    test_sensor_data_sca.append(standardization_test_sensor_data)

# 検証データ
val_sensor_data_sca = []
for i in range(len(val_sensor_data)):
    mean = np.mean(val_sensor_data[i])
    std = np.std(val_sensor_data[i])

    #標準化処理を実行
    standardization_val_sensor_data = (val_sensor_data[i] - mean) / std
    val_sensor_data_sca.append(standardization_val_sensor_data)
    
# データ長を揃える(最長のデータ+999)
# 最大の波形データ長を見つける
max_length = max(len(data) for data in sensor_data_sca + test_sensor_data_sca + val_sensor_data_sca)
max_length = max_length+999

# ゼロパディングを行う（学習データ）
padded_sensor_data = []
for data in sensor_data_sca:
    padding_length = max_length - len(data)
    padding_beginning = padding_length // 2
    padding_end = padding_length - padding_beginning
    padded_data = np.pad(data, (padding_beginning, padding_end), mode='constant', constant_values=0)
    padded_sensor_data.append(padded_data)

# ゼロパディングを行う（テストデータ）
padded_test_sensor_data = []
for data in test_sensor_data_sca:
    padding_length = max_length - len(data)
    padding_beginning = padding_length // 2
    padding_end = padding_length - padding_beginning
    padded_data = np.pad(data, (padding_beginning, padding_end), mode='constant', constant_values=0)
    padded_test_sensor_data.append(padded_data)

# ゼロパディングを行う（検証データ）
padded_val_sensor_data = []
for data in val_sensor_data_sca:
    padding_length = max_length - len(data)
    padding_beginning = padding_length // 2
    padding_end = padding_length - padding_beginning
    padded_data = np.pad(data, (padding_beginning, padding_end), mode='constant', constant_values=0)
    padded_val_sensor_data.append(padded_data)
    
# 学習データとテストデータをNumPyの配列に変換
padded_sensor_data = np.array(padded_sensor_data)
padded_test_sensor_data = np.array(padded_test_sensor_data)
padded_val_sensor_data = np.array(padded_val_sensor_data)

# チャンネル毎にデータを結合(学習データ)
ch = 6
concatenated_data_per_subject = []
for i in range(len(padded_sensor_data) // ch):  # 管の数だけループ
    subject_data = padded_sensor_data[i * ch:(i + 1) * ch]  # 同じ管のチャンネルのデータを取得
    concatenated_data = np.stack(subject_data, axis=-1)  # チャンネルのデータを1つの配列に連結
    concatenated_data_per_subject.append(concatenated_data)

# データをデータ長×8チャンネルの形状に整形する
reshaped_sensor_data = []
for data in concatenated_data_per_subject:
    reshaped_sensor_data.append(data.reshape(-1, ch))  # データ長×チャンネルの形状に変換し、リストに追加

reshaped_sensor_data = np.array(reshaped_sensor_data)  # リストをNumPy配列に変換


# チャンネル毎にデータを結合(テストデータ)
concatenated_data_per_subject = []
for i in range(len(padded_test_sensor_data) // ch):  # 管の数だけループ
    subject_data = padded_test_sensor_data[i * ch:(i + 1) * ch]  # 同じ管のチャンネルのデータを取得
    concatenated_data = np.stack(subject_data, axis=-1)  # チャンネルのデータを1つの配列に連結
    concatenated_data_per_subject.append(concatenated_data)


# データをデータ長×8チャンネルの形状に整形する
reshaped_test_sensor_data = []
for data in concatenated_data_per_subject:
    reshaped_test_sensor_data.append(data.reshape(-1, ch))  # データ長×チャンネルの形状に変換し、リストに追加

reshaped_test_sensor_data = np.array(reshaped_test_sensor_data)  # リストをNumPy配列に変換


# チャンネル毎にデータを結合(検証データ)
concatenated_data_per_subject = []
for i in range(len(padded_val_sensor_data) // ch):  # 管の数だけループ
    subject_data = padded_val_sensor_data[i * ch:(i + 1) * ch]  # 同じ管のチャンネルのデータを取得
    concatenated_data = np.stack(subject_data, axis=-1)  # チャンネルのデータを1つの配列に連結
    concatenated_data_per_subject.append(concatenated_data)

# データをデータ長×8チャンネルの形状に整形する
reshaped_val_sensor_data = []
for data in concatenated_data_per_subject:
    reshaped_val_sensor_data.append(data.reshape(-1, ch))  # データ長×チャンネルの形状に変換し、リストに追加

reshaped_val_sensor_data = np.array(reshaped_val_sensor_data)  # リストをNumPy配列に変換

# %%
def stacked_what_where_autoencoder(input_shape):
    # Encoder
    inputs = Input(shape=input_shape)
    conv1 = Conv1D(32, 10, activation='selu', padding='same')(inputs)
    pool1 = MaxPooling1D(pool_size=2, padding='same')(conv1)  
    conv2 = Conv1D(64, 5, activation='selu', padding='same')(pool1)
    pool2 = MaxPooling1D(pool_size=2, padding='same')(conv2)  

    # Decoder
    conv3 = Conv1DTranspose(64, 5, strides=2, activation='selu', padding='same')(pool2)
    conv4 = Conv1DTranspose(32, 10, strides=2, activation='selu', padding='same')(conv3)
    decoded = Conv1DTranspose(input_shape[-1], 7, padding='same')(conv4)  # 出力形状を入力形状と一致させる

    # Autoencoder Model
    autoencoder = Model(inputs, decoded)
    return autoencoder

# %%
# 入力データの形状を取得
input_shape = reshaped_sensor_data.shape[1:]

# Stacked What-Where Autoencoderを構築
autoencoder = stacked_what_where_autoencoder(input_shape)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# モデルのサマリを表示
autoencoder.summary()

# モデルの学習
history = autoencoder.fit(reshaped_sensor_data, reshaped_sensor_data, epochs=500, batch_size=16, shuffle=True, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 12300, 6)]        0
#
#  conv1d (Conv1D)             (None, 12300, 32)         1952
#
#  max_pooling1d (MaxPooling1D  (None, 6150, 32)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 6150, 64)          10304
#
#  max_pooling1d_1 (MaxPooling  (None, 3075, 64)         0
#  1D)
#
#  conv1d_transpose (Conv1DTra  (None, 6150, 64)         20544
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 12300, 32)        20512
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 12300, 6)         1350
#  ranspose)
#
# =================================================================
# Total params: 54,662
# Trainable params: 54,662
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 49/49 [==============================] - 6s 14ms/step - loss: 0.1340
# Epoch 2/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0345
# Epoch 3/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0209
# Epoch 4/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0147
# Epoch 5/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0110
# Epoch 6/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0093
# Epoch 7/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0085
# Epoch 8/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0071
# Epoch 9/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0065
# Epoch 10/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0059
# Epoch 11/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0054
# Epoch 12/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0058
# Epoch 13/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0050
# Epoch 14/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0048
# Epoch 15/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0046
# Epoch 16/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0046
# Epoch 17/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0043
# Epoch 18/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 19/500
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0042
# Epoch 20/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 21/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 22/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 23/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 24/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 25/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 26/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 27/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 28/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 29/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 30/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 31/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 32/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0030
# Epoch 33/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 34/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0033
# Epoch 35/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 36/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 37/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 38/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 39/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 40/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 41/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0026
# Epoch 42/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 43/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0028
# Epoch 44/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 45/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0025
# Epoch 46/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 47/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 48/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 49/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 50/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 51/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 52/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 53/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 54/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 55/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 56/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 57/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 58/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 59/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 60/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 61/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 62/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 63/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 64/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 65/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 66/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 67/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 68/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0021
# Epoch 69/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 70/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 71/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 72/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 73/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 74/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 75/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 76/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 77/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 78/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 79/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 80/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 81/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 82/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 83/500
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 84/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 85/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 86/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 87/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 88/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 89/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 90/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 91/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 92/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 93/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 94/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 95/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 96/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 97/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 98/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 99/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 100/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 101/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 102/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 103/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 104/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 105/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 106/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 107/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 108/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 109/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 110/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 111/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 112/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 113/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 114/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 115/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 116/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 117/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 118/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 119/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 120/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 121/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 122/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 123/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 124/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 125/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 126/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 127/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 128/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 129/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 130/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0020
# Epoch 131/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 132/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 133/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 134/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 135/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 136/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 137/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 138/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 139/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 140/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 141/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 142/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 143/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 144/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 145/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 146/500
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 147/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 148/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 149/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 150/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 151/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 152/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 153/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 154/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 155/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 156/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 157/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 158/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 159/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 160/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 161/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 162/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 163/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 164/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 165/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 166/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 167/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 168/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 169/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 170/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 171/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 172/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 173/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 174/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 175/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 176/500
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 177/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 178/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 179/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 180/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 181/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 182/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 183/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 184/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 185/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 186/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 187/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 188/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 189/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 190/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 191/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 192/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 193/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 194/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 195/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 196/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 197/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 198/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 199/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 200/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 201/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 202/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 203/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 204/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 205/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 206/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 207/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 208/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 209/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 210/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 211/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 212/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 213/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 214/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 215/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 216/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 217/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 218/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 219/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 220/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 221/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 222/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 223/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 224/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 225/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 226/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 227/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 228/500
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 229/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 230/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 231/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 232/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 233/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 234/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 235/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 236/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 237/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 238/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 239/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 240/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 241/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 242/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 243/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 244/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 245/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 246/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 247/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 248/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 249/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 250/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 251/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 252/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 253/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 254/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 255/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 256/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 257/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 258/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 259/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5577e-04
# Epoch 260/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 261/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 262/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 263/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 264/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 265/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 266/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 267/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 268/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 269/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 270/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 271/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 272/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 273/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 274/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 275/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 276/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 277/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 278/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 279/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 280/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 281/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 282/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 283/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 284/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 285/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 286/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 287/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6224e-04
# Epoch 288/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 289/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 290/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 291/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 292/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 293/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 294/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 295/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 296/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 297/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3405e-04
# Epoch 298/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8380e-04
# Epoch 299/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 300/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7108e-04
# Epoch 301/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 302/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5950e-04
# Epoch 303/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6153e-04
# Epoch 304/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1152e-04
# Epoch 305/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 306/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 307/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2953e-04
# Epoch 308/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 309/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8507e-04
# Epoch 310/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 311/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 312/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2691e-04
# Epoch 313/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 314/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 315/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 316/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5233e-04
# Epoch 317/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9462e-04
# Epoch 318/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 319/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9160e-04
# Epoch 320/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 321/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5293e-04
# Epoch 322/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7850e-04
# Epoch 323/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7271e-04
# Epoch 324/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9880e-04
# Epoch 325/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7548e-04
# Epoch 326/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 327/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6385e-04
# Epoch 328/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1508e-04
# Epoch 329/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7748e-04
# Epoch 330/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4614e-04
# Epoch 331/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5291e-04
# Epoch 332/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 333/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3458e-04
# Epoch 334/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6780e-04
# Epoch 335/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 336/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 337/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7249e-04
# Epoch 338/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 339/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 340/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7983e-04
# Epoch 341/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.0346e-04
# Epoch 342/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 343/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 344/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 345/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 346/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7256e-04
# Epoch 347/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3240e-04
# Epoch 348/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7065e-04
# Epoch 349/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6052e-04
# Epoch 350/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9717e-04
# Epoch 351/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5218e-04
# Epoch 352/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 353/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 354/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5425e-04
# Epoch 355/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7985e-04
# Epoch 356/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2502e-04
# Epoch 357/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 358/500
# 49/49 [==============================] - 1s 12ms/step - loss: 8.9352e-04
# Epoch 359/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4380e-04
# Epoch 360/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6142e-04
# Epoch 361/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.0970e-04
# Epoch 362/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3158e-04
# Epoch 363/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2784e-04
# Epoch 364/500
# 49/49 [==============================] - 1s 12ms/step - loss: 8.9953e-04
# Epoch 365/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4447e-04
# Epoch 366/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.9123e-04
# Epoch 367/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9331e-04
# Epoch 368/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8635e-04
# Epoch 369/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 370/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.6396e-04
# Epoch 371/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2658e-04
# Epoch 372/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4757e-04
# Epoch 373/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 374/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0688
# Epoch 375/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0073
# Epoch 376/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 377/500
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0027
# Epoch 378/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 379/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 380/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 381/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 382/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 383/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 384/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 385/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 386/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 387/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 388/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 389/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 390/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 391/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 392/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0018
# Epoch 393/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 394/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 395/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 396/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 397/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 398/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015
# Epoch 399/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 400/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 401/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 402/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 403/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 404/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 405/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 406/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 407/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 408/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 409/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 410/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 411/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 412/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 413/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 414/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 415/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 416/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 417/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 418/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 419/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 420/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 421/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 422/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 423/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 424/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 425/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 426/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 427/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 428/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 429/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 430/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 431/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 432/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 433/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 434/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8365e-04
# Epoch 435/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 436/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 437/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 438/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 439/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9018e-04
# Epoch 440/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 441/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8718e-04
# Epoch 442/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 443/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 444/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 445/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 446/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 447/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 448/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6822e-04
# Epoch 449/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 450/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6838e-04
# Epoch 451/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 452/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.9899e-04
# Epoch 453/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 454/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 455/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1823e-04
# Epoch 456/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 457/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 458/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 459/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 460/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 461/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 462/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.9081e-04
# Epoch 463/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 464/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6426e-04
# Epoch 465/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.8744e-04
# Epoch 466/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5570e-04
# Epoch 467/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4705e-04
# Epoch 468/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7354e-04
# Epoch 469/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 470/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 471/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.0806e-04
# Epoch 472/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 473/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 474/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 475/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7667e-04
# Epoch 476/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 477/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 478/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6360e-04
# Epoch 479/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 480/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 481/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 482/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.6558e-04
# Epoch 483/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2175e-04
# Epoch 484/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7150e-04
# Epoch 485/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4662e-04
# Epoch 486/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.9098e-04
# Epoch 487/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.0837e-04
# Epoch 488/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1616e-04
# Epoch 489/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 490/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3585e-04
# Epoch 491/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 492/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.0349e-04
# Epoch 493/500
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7435e-04
# Epoch 494/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 495/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 496/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 497/500
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011
# Epoch 498/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.4916e-04
# Epoch 499/500
# 49/49 [==============================] - 1s 11ms/step - loss: 8.1689e-04
# Epoch 500/500
# 49/49 [==============================] - 1s 10ms/step - loss: 9.5839e-04

# %%
# 損失関数の値を取得
loss = history.history['loss']

# エポックごとの損失関数の変化をプロット
plt.plot(loss)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# テストデータの再構築を行い再構成誤差を計算する
reconstructed_test_data = autoencoder.predict(reshaped_test_sensor_data)
mse_test = np.mean(np.square(reshaped_test_sensor_data - reconstructed_test_data), axis=(1, 2))
# Out:
# 3/3 [==============================] - 1s 59ms/step

# %%
# 学習データの再構成を行い再構成誤差を計算する
reconstructed_data = autoencoder.predict(reshaped_sensor_data)
mse = np.mean(np.square(reshaped_sensor_data - reconstructed_data), axis=(1, 2))
# Out:
# 25/25 [==============================] - 0s 10ms/step

# %%
# 検証データの再構築を行い再構成誤差を計算する
reconstructed_val_data = autoencoder.predict(reshaped_val_sensor_data)
mse_val = np.mean(np.square(reshaped_val_sensor_data - reconstructed_val_data), axis=(1, 2))
# Out:
# 2/2 [==============================] - 0s 323ms/step

# %%
# ヒストグラムの作成
weights1 = np.ones(len(mse))/float(len(mse))
weights2 = np.ones(len(mse_test))/float(len(mse_test))
weights3 = np.ones(len(mse_val))/float(len(mse_val))
plt.hist(mse, bins=50, alpha=0.5, label='train',weights=weights1 )  # 学習データのヒストグラムをプロット
plt.hist(mse_test, bins=50, alpha=0.5, label='test', weights=weights2)  # テストデータのヒストグラムをプロット
plt.hist(mse_val, bins=50, alpha=0.5, label='val', weights=weights3)  # 検証データのヒストグラムをプロット
plt.xlabel('anomalyscore')
plt.ylabel('Proportion')
plt.legend()  # 凡例を表示
plt.show()

# %%
# ヒストグラムの作成
weights2 = np.ones(len(mse_test))/float(len(mse_test))
weights3 = np.ones(len(mse_val))/float(len(mse_val))
plt.hist(mse_val, bins=50, alpha=0.5, label='OK_Test', weights=weights3)  # 検証データのヒストグラムをプロット
plt.hist(mse_test, bins=50, alpha=0.5, label='NG_Test', weights=weights2)  # テストデータのヒストグラムをプロット
plt.xlabel('anomalyscore')
plt.ylabel('Proportion')
plt.legend()  # 凡例を表示
plt.show()

# %%
plt.hist(mse, bins=50, alpha=0.5, label='OK', weights=weights1)  # テストデータのヒストグラムをプロット
plt.hist(mse_val, bins=50, alpha=0.5, label='OK_Test', weights=weights3)  # 検証データのヒストグラムをプロット
plt.xlabel('anomalyscore')
plt.ylabel('Proportion')
plt.legend()  # 凡例を表示
plt.show()

# %%
# Figureを作成し、2つのサブプロットを配置する
fig, axes = plt.subplots(3, 2, figsize=(8, 10), sharex=True, sharey=True)

H = 2
V = 3
n = 0

# 上段左のサブプロットにプロットする
axes[0,0].plot(reshaped_sensor_data[n,:,H])
axes[0,0].set_title('OK_original_H')
plt.ylim(-15,15)
# 中段左のサブプロットにプロットする
axes[1,0].plot(reconstructed_data[n,:,H])
axes[1,0].set_title('OK_reconstructed_H')
# 下段左のサブプロットにプロットする
axes[2,0].plot(reshaped_sensor_data[n,:,H]-reconstructed_data[n,:,H])
axes[2,0].set_title('OK_original_H - OK_reconstructed_H')

# 上段右のサブプロットにプロットする
axes[0,1].plot(reshaped_sensor_data[n,:,V])
axes[0,1].set_title('OK_original_V')
# 中段右のサブプロットにプロットする
axes[1,1].plot(reconstructed_data[n,:,V])
axes[1,1].set_title('OK_reconstructed_V')
# 下段右のサブプロットにプロットする
axes[2,1].plot(reshaped_sensor_data[n,:,V]-reconstructed_data[n,:,V])
axes[2,1].set_title('OK_original_V - OK_reconstructed_V')

# グラフのレイアウトを整える
plt.tight_layout()

# グラフを表示する
plt.show()

# %%
#健全なテスト用データのプロット
fig, axes = plt.subplots(3, 2, figsize=(8, 10), sharex=True, sharey=True)

H = 0
V = 1
n = 20

# 上段左のサブプロットにプロットする
axes[0,0].plot(reshaped_val_sensor_data[n,:,H])
axes[0,0].set_title('OK_original_H')
# 中段左のサブプロットにプロットする
axes[1,0].plot(reconstructed_val_data[n,:,H])
axes[1,0].set_title('OK_reconstructed_H')
# 下段左のサブプロットにプロットする
axes[2,0].plot(reshaped_val_sensor_data[n,:,H]-reconstructed_val_data[n,:,H])
axes[2,0].set_title('OK_original_H - OK_reconstructed_H')

# 上段右のサブプロットにプロットする
axes[0,1].plot(reshaped_val_sensor_data[n,:,V])
axes[0,1].set_title('OK_original_V')
# 中段右のサブプロットにプロットする
axes[1,1].plot(reconstructed_val_data[n,:,V])
axes[1,1].set_title('OK_reconstructed_V')
# 下段右のサブプロットにプロットする
axes[2,1].plot(reshaped_val_sensor_data[n,:,V]-reconstructed_val_data[n,:,V])
axes[2,1].set_title('OK_original_V - OK_reconstructed_V')

# グラフのレイアウトを整える
plt.tight_layout()

# グラフを表示する
plt.show()

# %%
#きず有りテスト用データのプロット
fig, axes = plt.subplots(3, 2, figsize=(8, 10), sharex=True, sharey=True)

H = 2
V = 3
n = 9

# 上段左のサブプロットにプロットする
axes[0,0].plot(reshaped_test_sensor_data[n,:,H])
axes[0,0].set_title('NG_test_H')
# 中段左のサブプロットにプロットする
axes[1,0].plot(reconstructed_test_data[n,:,H])
axes[1,0].set_title('NG_test_reconstructed_H')
# 下段左のサブプロットにプロットする
axes[2,0].plot(reshaped_test_sensor_data[n,:,H]-reconstructed_test_data[n,:,H])
axes[2,0].set_title('NG_test_H - NG_test_reconstructed_H')

# 上段右のサブプロットにプロットする
axes[0,1].plot(reshaped_test_sensor_data[n,:,V])
axes[0,1].set_title('NG_test_V')
# 中段右のサブプロットにプロットする
axes[1,1].plot(reconstructed_test_data[n,:,V])
axes[1,1].set_title('NG_test_reconstructed_V')
# 下段右のサブプロットにプロットする
axes[2,1].plot(reshaped_test_sensor_data[n,:,V]-reconstructed_test_data[n,:,V])
axes[2,1].set_title('NG_test_V - NG_test_reconstructed_V')

# グラフのレイアウトを整える
plt.tight_layout()

# グラフを表示する
plt.show()

# %%
#　各管のデータを色調表示する。
import matplotlib.pyplot as plt
n = 1
# カラースケールの最小値と最大値を設定
vmin = min(np.min(reshaped_sensor_data[n,:,:]), np.min(reconstructed_data[n,:,:]))
vmax = max(np.max(reshaped_sensor_data[n,:,:]), np.max(reconstructed_data[n,:,:]))

plt.figure(figsize=(10, 10))

# input_Train_OK
plt.subplot(311)
plt.imshow(reshaped_sensor_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('input_Train_OK')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# output_Train_OK
plt.subplot(312)
plt.imshow(reconstructed_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('output_Train_OK')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# input - output
plt.subplot(313)
plt.imshow((reshaped_sensor_data[n,:,:] - reconstructed_data[n,:,:]).T, cmap='jet', aspect='auto', vmin=vmin/10, vmax=vmax/10)
plt.colorbar(label='amplitude')
plt.title('input - output')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

plt.tight_layout()
plt.show()

# %%
#　各管のデータを色調表示する。
n = 9
# カラースケールの最小値と最大値を設定
vmin = min(np.min(reshaped_sensor_data[n,:,:]), np.min(reconstructed_data[n,:,:]))
vmax = max(np.max(reshaped_sensor_data[n,:,:]), np.max(reconstructed_data[n,:,:]))

plt.figure(figsize=(10, 10))

# input_Train_OK
plt.subplot(311)
plt.imshow(reshaped_test_sensor_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('input_Test_NG')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# output_Train_OK
plt.subplot(312)
plt.imshow(reconstructed_test_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('output_Test_NG')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# input - output
plt.subplot(313)
plt.imshow((reshaped_test_sensor_data[n,:,:] - reconstructed_test_data[n,:,:]).T, cmap='jet', aspect='auto', vmin=vmin/10, vmax=vmax/10)
plt.colorbar(label='amplitude')
plt.title('input - output')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

plt.tight_layout()
plt.show()

# %%
#　各管のデータを色調表示する。
n = 20
# カラースケールの最小値と最大値を設定
vmin = min(np.min(reshaped_sensor_data[n,:,:]), np.min(reconstructed_data[n,:,:]))
vmax = max(np.max(reshaped_sensor_data[n,:,:]), np.max(reconstructed_data[n,:,:]))

plt.figure(figsize=(10, 10))

# input_Train_OK
plt.subplot(311)
plt.imshow(reshaped_val_sensor_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('input_Test_OK')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# output_Train_OK
plt.subplot(312)
plt.imshow(reconstructed_val_data[n,:,:].T, cmap='jet', aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='amplitude')
plt.title('output_Test_OK')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

# input - output
plt.subplot(313)
plt.imshow((reshaped_val_sensor_data[n,:,:] - reconstructed_val_data[n,:,:]).T, cmap='jet', aspect='auto', vmin=vmin/10, vmax=vmax/10)
plt.colorbar(label='amplitude')
plt.title('input - output')
plt.xlabel('Sample')
plt.ylabel('Test Frequency')
plt.yticks([0, 1, 2, 3, 4, 5], ['F1H', 'F1V', 'F2H', 'F2V', 'F3H', 'F3V'])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.imshow(padded_sensor_data[1001:2000], aspect='auto', cmap='jet', vmin=-3, vmax=3)
plt.colorbar(label='Value')
plt.xlabel('Time')
plt.ylabel('Sample')
plt.title('Padded Sensor Data')
plt.show()

# %%
whos
# Out:
# Variable                               Type          Data/Info
# --------------------------------------------------------------
# Adam                                   type          <class 'keras.optimizers.optimizer_v2.adam.Adam'>
# Conv1D                                 type          <class 'keras.layers.conv<...>olutional.conv1d.Conv1D'>
# Conv1DTranspose                        type          <class 'keras.layers.conv<...>anspose.Conv1DTranspose'>
# H                                      int           2
# Input                                  function      <function Input at 0x000001C7D2E42320>
# MaxPooling1D                           type          <class 'keras.layers.pool<...>_pooling1d.MaxPooling1D'>
# Model                                  type          <class 'keras.engine.training.Model'>
# UpSampling1D                           type          <class 'keras.layers.resh<...>sampling1d.UpSampling1D'>
# V                                      int           3
# ZeroPadding1D                          type          <class 'keras.layers.resh<...>padding1d.ZeroPadding1D'>
# abs_sensor_data                        list          n=6256
# abs_test_sensor_data                   list          n=688
# abs_val_sensor_data                    list          n=488
# autoencoder                            Functional    <keras.engine.functional.<...>ct at 0x000001C8BF49A4D0>
# axes                                   ndarray       3x2: 6 elems, type `object`, 48 bytes
# backward_index                         NoneType      None
# ch                                     int           6
# concatenated_data                      ndarray       12300x6: 73800 elems, type `float64`, 590400 bytes (576.5625 kb)
# concatenated_data_per_subject          list          n=61
# data                                   ndarray       12300x6: 73800 elems, type `float64`, 590400 bytes (576.5625 kb)
# data_filenames                         list          n=839
# data_matrix                            list          n=6256
# desired_index                          int           500
# empty_lists_sensor_data_indices        list          n=0
# empty_lists_test_sensor_data_indices   list          n=0
# empty_lists_val_sensor_data_indices    list          n=0
# extension_number                       int           0
# fig                                    Figure        Figure(800x1000)
# filedialog                             module        <module 'tkinter.filedial<...>\tkinter\\filedialog.py'>
# folder_selected                        str           C:/Users/r-fujita/Desktop/20240307/train
# forward_index                          NoneType      None
# history                                History       <keras.callbacks.History <...>ct at 0x000001C8BF629630>
# i                                      int           60
# index                                  int           3024
# indices_to_remove                      list          n=0
# input_shape                            tuple         n=2
# key                                    str           C:/Users/r-fujita/Desktop<...>-2316A\APD000\004-028_0_8
# load_binary_data                       function      <function load_binary_data at 0x000001C7D5B6D2D0>
# load_test_data                         function      <function load_test_data at 0x000001C88DECACB0>
# load_val_data                          function      <function load_val_data at 0x000001C929913EB0>
# loss                                   list          n=25
# max_length                             int           12300
# mean                                   float64       63.581539368917724
# mean_squared_error                     function      <function mean_squared_er<...>or at 0x000001C7CAAE4B80>
# mse                                    ndarray       781: 781 elems, type `float64`, 6248 bytes
# mse_test                               ndarray       86: 86 elems, type `float64`, 688 bytes
# mse_val                                ndarray       61: 61 elems, type `float64`, 488 bytes
# n                                      int           0
# n1                                     int           0
# n2                                     int           1
# n3                                     int           2
# n4                                     int           3
# n5                                     int           4
# n6                                     int           5
# np                                     module        <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# num_samples                            int           6256
# num_sensors                            int           8
# num_test_samples                       int           688
# num_val_samples                        int           488
# os                                     module        <module 'os' from 'C:\\Pr<...>\\Python310\\lib\\os.py'>
# padded_data                            ndarray       12300: 12300 elems, type `float64`, 98400 bytes
# padded_sensor_data                     ndarray       4686x12300: 57637800 elems, type `float64`, 461102400 bytes (439.74151611328125 Mb)
# padded_test_sensor_data                ndarray       516x12300: 6346800 elems, type `float64`, 50774400 bytes (48.4222412109375 Mb)
# padded_val_sensor_data                 ndarray       366x12300: 4501800 elems, type `float64`, 36014400 bytes (34.34600830078125 Mb)
# padding_beginning                      int           2759
# padding_end                            int           2759
# padding_length                         int           5518
# pd                                     module        <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                                    module        <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# re                                     module        <module 're' from 'C:\\Pr<...>\\Python310\\lib\\re.py'>
# reconstructed_data                     ndarray       781x12300x6: 57637800 elems, type `float32`, 230551200 bytes (219.87075805664062 Mb)
# reconstructed_test_data                ndarray       86x12300x6: 6346800 elems, type `float32`, 25387200 bytes (24.21112060546875 Mb)
# reconstructed_val_data                 ndarray       61x12300x6: 4501800 elems, type `float32`, 18007200 bytes (17.173004150390625 Mb)
# reshaped_sensor_data                   ndarray       781x12300x6: 57637800 elems, type `float64`, 461102400 bytes (439.74151611328125 Mb)
# reshaped_test_sensor_data              ndarray       86x12300x6: 6346800 elems, type `float64`, 50774400 bytes (48.4222412109375 Mb)
# reshaped_val_sensor_data               ndarray       61x12300x6: 4501800 elems, type `float64`, 36014400 bytes (34.34600830078125 Mb)
# root                                   Tk            .
# sample                                 list          n=1
# sensor_data                            list          n=4686
# sensor_data_copy                       list          n=4686
# sensor_data_dict                       dict          n=6256
# sensor_data_sca                        list          n=4686
# sensor_key                             str           C:/Users/r-fujita/Desktop<...>-2316B\APD003\023-001_1_8
# sensor_value                           list          n=8480
# sensor_values                          list          n=8480
# stacked_what_where_autoencoder         function      <function stacked_what_wh<...>er at 0x000001C8879CCE50>
# standardization_sensor_data            ndarray       6094: 6094 elems, type `float64`, 48752 bytes
# standardization_test_sensor_data       ndarray       8612: 8612 elems, type `float64`, 68896 bytes
# standardization_val_sensor_data        ndarray       6782: 6782 elems, type `float64`, 54256 bytes
# std                                    float64       110.46719397613715
# subject_data                           ndarray       6x12300: 73800 elems, type `float64`, 590400 bytes (576.5625 kb)
# test_data                              dict          n=86
# test_data_filenames                    list          n=91
# test_data_matrix                       list          n=688
# test_folder_path                       str           C:/Users/r-fujita/Desktop/20240307/test
# test_sensor_data                       list          n=516
# test_sensor_data_copy                  list          n=516
# test_sensor_data_dict                  dict          n=688
# test_sensor_data_sca                   list          n=516
# test_sensor_key                        str           C:/Users/r-fujita/Desktop<...>-2316A\APD000\004-028_0_8
# test_sensor_value                      list          n=10416
# test_sensor_values                     list          n=10416
# tf                                     module        <module 'tensorflow' from<...>tensorflow\\__init__.py'>
# tk                                     module        <module 'tkinter' from 'C<...>b\\tkinter\\__init__.py'>
# unsigned2signed                        function      <function unsigned2signed at 0x000001C7D5B6D000>
# val_data                               dict          n=61
# val_data_filenames                     list          n=61
# val_data_matrix                        list          n=488
# val_folder_path                        str           C:/Users/r-fujita/Desktop/20240307/val
# val_sensor_data                        list          n=366
# val_sensor_data_copy                   list          n=366
# val_sensor_data_dict                   dict          n=488
# val_sensor_data_sca                    list          n=366
# val_sensor_key                         str           C:/Users/r-fujita/Desktop<...>-2316B\APD004\029-014_0_8
# val_sensor_value                       list          n=8704
# val_sensor_values                      list          n=8704
# waveform                               list          n=8704
# weights1                               ndarray       781: 781 elems, type `float64`, 6248 bytes
# weights2                               ndarray       86: 86 elems, type `float64`, 688 bytes
# weights3                               ndarray       61: 61 elems, type `float64`, 488 bytes
