# %%
import os
import glob
import tkinter as tk
from tkinter import filedialog
import struct
import pandas as pd
import re

def select_folder():
    """
    フォルダ選択ダイアログを表示し、選択されたフォルダのパスを返します。
    """
    root = tk.Tk()
    root.withdraw()  # GUIを隠す
    folder_path = filedialog.askdirectory()
    return folder_path

def find_t0_files(folder_path):
    """
    指定されたフォルダ内の全てのサブフォルダを再帰的に探索し、
    .t0または.T0の拡張子を持つファイルのパスをリストで返します。

    Args:
        folder_path (str): 検索対象のフォルダのパス
    """
    t0_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if re.search(r'\.[tT]0\d*\.?\w*', file):  # .t0または.T0を含む拡張子を探す
                t0_files.append(os.path.join(root, file))
    return t0_files

def load_sensor_data(file_path):
    """
    指定されたファイルパスからセンサデータを読み込み、
    各センサの値をリストとして返します。

    Args:
        file_path (str): センサデータファイルのパス
    """
    with open(file_path, 'rb') as file:
        data = file.read()

    sensor_data = [data[i:i+8*2] for i in range(408, len(data), 8*2)]
    sensor_values = [[] for _ in range(8)]
    for sensor in sensor_data:
        for i in range(8):
            sensor_value = unsigned2signed(int.from_bytes(sensor[i*2:i*2+2], 'little'))
            sensor_values[i].append(sensor_value)
    
    return sensor_values

def unsigned2signed(unsigned_value):
    """
    符号なし16ビット整数を符号付き16ビット整数に変換します。

    Args:
        unsigned_value (int): 符号なし16ビット整数
    """
    if unsigned_value >= 32768:
        return unsigned_value - 65536
    else:
        return unsigned_value

def write_to_excel(sensor_values, file_name, save_dir):
    """
    センサ値をExcelファイルに書き込みます。

    Args:
        sensor_values: センサ値のリスト
        file_name: 保存するファイル名
        save_dir: 保存するディレクトリ
    """
    excel_file_name = os.path.join(save_dir, f"{file_name}.xlsx")
    df = pd.DataFrame(sensor_values).T  # 転置して各センサーが列になるようにする
    df.columns = [f'Sensor_{i+1}' for i in range(8)]
    df.to_excel(excel_file_name, index=False)
    print(f"{excel_file_name} に書き出しました。")

def process_subfolders(base_folder, save_base_folder):
    """
    指定されたフォルダ内の全てのサブフォルダを処理します。

    Args:
        base_folder (str): 処理対象のフォルダのパス
        save_base_folder (str): Excelファイルを保存するフォルダのパス
    """
    subfolders = [f.path for f in os.scandir(base_folder) if f.is_dir()]
    for subfolder in subfolders:
        subfolder_name = os.path.basename(subfolder)
        save_dir = os.path.join(save_base_folder, subfolder_name)
        os.makedirs(save_dir, exist_ok=True)
        
        t0_files = find_t0_files(subfolder)
        if not t0_files:
            print(f"{subfolder} 内に拡張子に.t0を含むファイルが見つかりませんでした。")
            continue

        for file_path in t0_files:
            file_name = os.path.basename(file_path).split('.')[0]  # 拡張子を除いたファイル名
            sensor_values = load_sensor_data(file_path)
            write_to_excel(sensor_values, file_name, save_dir)

def main():
    base_folder = select_folder()
    if not base_folder:
        print("フォルダが選択されませんでした。")
        return

    save_base_folder = r"C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課"
    process_subfolders(base_folder, save_base_folder)

if __name__ == "__main__":
    main()
# Out:
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-202A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-202A\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-202A\013-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-202B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-202B\013-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\015-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\015-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207D\015-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\019-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-207F_27\019-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-210B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-210C\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-210C\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-210C\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-210C\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-216\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-421A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-421B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-421B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-425\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-425\018-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-425\018-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-425\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426A\001-003.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426A\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426A\004-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426A\020-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426A\003-025.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426B\001-003.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426C\001-003.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426C\004-027.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-426C\004-027.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-461\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-462\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-462\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-462\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-464\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-505\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-505\006-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-505\006-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506A\006-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506C\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506C\018-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-506C\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510D\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510E\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510E\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510E\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510E\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-510H\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-606A\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621A\003-003.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621A\027-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621B\001-014.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621B\001-014.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621B\021-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-621B\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-628A\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-633\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-633\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-644B\001-002.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-733\001-001.xlsx に書き出しました。
# C:\Users\r-fujita\Desktop\ET\藤澤さんデータ\リスト1課\UE-733\001-001.xlsx に書き出しました。

# %%
import os
import pandas as pd

def find_excel_files_with_outliers(folder_path, threshold=30000):
    """
    指定されたフォルダ内の全てのサブフォルダを再帰的に探索し、
    30000以上もしくは-30000以下の数値を含むExcelファイルのパスを出力します。

    Args:
        folder_path (str): 検索対象のフォルダのパス
        threshold (int): 閾値
    """
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".xlsx"):
                filepath = os.path.join(root, file)
                try:
                    df = pd.read_excel(filepath)
                    if df.values.max() >= threshold or df.values.min() <= -threshold:
                        print(filepath)
                except Exception as e:
                    print(f"Error reading {filepath}: {e}")

if __name__ == "__main__":
    folder_path = r"C:\Users\r-fujita\Desktop\ET\教師データExcel"
    find_excel_files_with_outliers(folder_path)
